# %%
mystr ="runoob"
print(mystr[3])
# Out:
# o

# %%
import math
# math.trunc(15)
print( math.trunc(15.5))
# Out:
# 15

# %%
print(0.1 + 0.2 == 0.3)  # 输出: False
print(0.1+0.2)
# Out:
# False
# 0.30000000000000004
